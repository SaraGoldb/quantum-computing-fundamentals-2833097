# %%
from qiskit import *
from qiskit.visualization import plot_histogram
# %matplotlib inline

# %%
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)
circuit.measure_all()
circuit.draw(output='mpl')

# %%
# UPDATE: Code updated after recording to resolve breaking changes from Qiskit 1.0
from qiskit.providers.basic_provider import BasicProvider
simulator = BasicProvider().get_backend('basic_simulator')
compiled_circuit = transpile(circuit, simulator)
result = simulator.run(compiled_circuit).result()
plot_histogram(result.get_counts())

# %%
# UPDATE: Code updated after recording to resolve breaking changes from Qiskit 1.0
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
service = QiskitRuntimeService(channel='ibm_quantum', token='dcf77f2a73702660dceb6b4e3fb4e919241f6ad5cf7a2efd069ea6e7c0a0d233d0d1905848c0e6336d73c1a21ab875e593c645f476f92a14ed784d371ea79f26')

# %%
# UPDATE: Code updated after recording to resolve breaking changes from Qiskit 1.0
qcomp = service.least_busy(operational=True, simulator=False) # select least busy quantum computer

pm = generate_preset_pass_manager(backend=qcomp, optimization_level=1) # optimize the circuit for quantum execution
isa_circuit = pm.run(circuit) # modify circuit for qcomp's specific Instruction Set Architecture (ISA)

sampler = Sampler(qcomp)
job = sampler.run([isa_circuit])
result = job.result()
plot_histogram(result[0].data.meas.get_counts())
# NOTE: This may take a while... You can check job status on the IBM Quantum Platform web dashboard.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       7 sampler = Sampler(qcomp)
#       8 job = sampler.run([isa_circuit])
# ----> 9 result = job.result()
#      10 plot_histogram(result[0].data.meas.get_counts())
#      11 # NOTE: This may take a while... You can check job status on the IBM Quantum Platform web dashboard.
#
# File ~/.local/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:135, in RuntimeJobV2.result(self, timeout, decoder)
#     120 """Return the results of the job.
#     121
#     122 Args:
#    (...)
#     132     RuntimeInvalidStateError: If the job was cancelled, and attempting to retrieve result.
#     133 """
#     134 _decoder = decoder or self._final_result_decoder
# --> 135 self.wait_for_final_state(timeout=timeout)
#     136 if self._status == "ERROR":
#     137     error_message = self._reason if self._reason else self._error_message
#
# File ~/.local/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:255, in RuntimeJobV2.wait_for_final_state(self, timeout)
#     253     self._ws_client_future = self._executor.submit(self._start_websocket_client)
#     254 if self._is_streaming():
# --> 255     self._ws_client_future.result(timeout)
#     256 # poll for status after stream has closed until status is final
#     257 # because status doesn't become final as soon as stream closes
#     258 status = self.status()
#
# File ~/.python/current/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File ~/.python/current/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
